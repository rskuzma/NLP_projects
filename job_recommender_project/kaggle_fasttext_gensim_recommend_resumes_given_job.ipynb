# %% [markdown]
# Credit to https://radimrehurek.com/gensim/auto_examples/tutorials/run_fasttext.html#sphx-glr-download-auto-examples-tutorials-run-fasttext-py -- Gensim fastText model and use on Lee Corpus. FastText made by FB research

# %%
import operator
import numpy as np

# %%
# %matplotlib inline

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# Here, we'll learn to work with fastText library for training word-embedding
# models, saving & loading them and performing similarity operations & vector
# lookups analogous to Word2Vec.

# %% [markdown]
# When to use FastText?
# ---------------------
#
# The main principle behind `fastText <https://github.com/facebookresearch/fastText>`_
# is that it treats each word as the aggregation of its subwords. Subwords are character n-grams of the word. The vector for a word is simply taken to be the sum of all vectors of its component char-ngrams.
#
#
# According to a detailed comparison of Word2Vec and FastText in `this notebook <https://github.com/RaRe-Technologies/gensim/blob/develop/docs/notebooks/Word2Vec_FastText_Comparison.ipynb>`__, fastText does significantly better on syntactic tasks as compared to the original Word2Vec, especially when the size of the training corpus is small. Word2Vec slightly outperforms FastText on semantic tasks though. The differences grow smaller as the size of training corpus increases.
#
#
# Training time for fastText is significantly higher than the Gensim version of Word2Vec (\ ``15min 42s`` vs ``6min 42s`` on text8, 17 mil tokens, 5 epochs, and a vector size of 100).
#
#
# fastText can be used to obtain vectors for out-of-vocabulary (OOV) words, by summing up vectors for its component char-ngrams, provided at least one of the char-ngrams was present in the training data.

# %% [markdown]
# ## Load Resume Data

# %%
import pandas as pd

# resumes only for now
# gives df with list of strings (tokenized) as well as lemmatized list of strings
local_resume_cleaned_lemmatized_tokenized_path = '/Users/richardkuzma/coding/NLP_projects/job_recommender_project/data/cleaned_lemmatized_tokenized_resume_dataset_maitrip.csv'

resumes = pd.read_csv(local_resume_cleaned_lemmatized_tokenized_path)
resumes.head()
resumes_sentences = resumes['lemmatized_resume'].tolist()
# Out:
#    ID Category                                       dirty_resume  \
# 0   1       HR  b'John H. Smith, P.H.R.\n800-991-5187 | PO Box...
# 1   2       HR  b'Name Surname\nAddress\nMobile No/Email\nPERS...
# 2   3       HR  b'Anthony Brown\nHR Assistant\nAREAS OF EXPERT...
# 3   4       HR  b'www.downloadmela.com\nSatheesh\nEMAIL ID:\nC...
# 4   5       HR  b"HUMAN RESOURCES DIRECTOR\n\xef\x82\xb7Expert...
#
#                                               resume  \
# 0  john h smith phr    po box  callahan fl  infog...
# 1  name surname address mobile noemail personal p...
# 2  anthony brown hr assistant areas expertise per...
# 3   satheesh email id career objective pursue gro...
# 4  human resources director expert organizational...
#
#                                     tokenized_resume  \
# 0  ['john', 'h', 'smith', 'phr', 'po', 'box', 'ca...
# 1  ['name', 'surname', 'address', 'mobile', 'noem...
# 2  ['anthony', 'brown', 'hr', 'assistant', 'areas...
# 3  ['satheesh', 'email', 'id', 'career', 'objecti...
# 4  ['human', 'resources', 'director', 'expert', '...
#
#                                    lemmatized_resume
# 0  ['john', 'h', 'smith', 'phr', 'po', 'box', 'ca...
# 1  ['name', 'surname', 'address', 'mobile', 'noem...
# 2  ['anthony', 'brown', 'hr', 'assistant', 'area'...
# 3  ['satheesh', 'email', 'id', 'career', 'objecti...
# 4  ['human', 'resource', 'director', 'expert', 'o...

# %% [markdown]
# Training models
# ---------------

# %% [markdown]
# For the following examples, we'll use the Lee Corpus (which you already have if you've installed gensim) for training our model.

# %%
#this may be annoying later...
from pprint import pprint



from gensim.models.fasttext import FastText as FT_gensim
from gensim.test.utils import datapath

# Set file names for train and test data
#corpus_file = datapath('lee_background.cor')
# Out:
# 2020-04-16 13:44:26,423 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 13:44:26,425 : INFO : built Dictionary(12 unique tokens: ['computer', 'human', 'interface', 'response', 'survey']...) from 9 documents (total 29 corpus positions)

# %%
model = FT_gensim(size=100)

# build the vocabulary
model.build_vocab(sentences = resumes_sentences)

# train the model
model.train(
    sentences=resumes_sentences, epochs=model.epochs,
    total_examples=model.corpus_count, total_words=model.corpus_total_words
)

print(model)
# Out:
# 2020-04-16 13:44:37,433 : INFO : resetting layer weights
# 2020-04-16 13:45:04,598 : INFO : collecting all words and their counts
# 2020-04-16 13:45:04,674 : WARNING : Each 'sentences' item should be a list of words (usually unicode strings). First item here is instead plain <class 'str'>.
# 2020-04-16 13:45:04,711 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-04-16 13:45:06,740 : INFO : collected 31 word types from a corpus of 8591130 raw words and 1219 sentences
# 2020-04-16 13:45:06,746 : INFO : Loading a fresh vocabulary
# 2020-04-16 13:45:06,751 : INFO : effective_min_count=5 retains 31 unique words (100% of original 31, drops 0)
# 2020-04-16 13:45:06,767 : INFO : effective_min_count=5 leaves 8591130 word corpus (100% of original 8591130, drops 0)
# 2020-04-16 13:45:06,781 : INFO : deleting the raw counts dictionary of 31 items
# 2020-04-16 13:45:06,789 : INFO : sample=0.001 downsamples 26 most-common words
# 2020-04-16 13:45:06,796 : INFO : downsampling leaves estimated 1512884 word corpus (17.6% of prior 8591130)
# 2020-04-16 13:45:06,801 : INFO : estimated required memory for 31 words, 31 buckets and 100 dimensions: 54436 bytes
# 2020-04-16 13:45:06,802 : INFO : resetting layer weights
# 2020-04-16 13:45:21,654 : INFO : training model with 3 workers on 31 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2020-04-16 13:45:22,734 : INFO : EPOCH 1 - PROGRESS: at 13.13% examples, 183802 words/s, in_qsize 6, out_qsize 1
# 2020-04-16 13:45:23,738 : INFO : EPOCH 1 - PROGRESS: at 26.74% examples, 197944 words/s, in_qsize 4, out_qsize 1
# 2020-04-16 13:45:24,745 : INFO : EPOCH 1 - PROGRESS: at 55.37% examples, 276507 words/s, in_qsize 4, out_qsize 1
# 2020-04-16 13:45:25,757 : INFO : EPOCH 1 - PROGRESS: at 74.49% examples, 273860 words/s, in_qsize 5, out_qsize 0
# 2020-04-16 13:45:26,733 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-16 13:45:26,734 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-16 13:45:26,746 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-16 13:45:26,747 : INFO : EPOCH - 1 : training on 8591130 raw words (1501456 effective words) took 5.0s, 299073 effective words/s
# 2020-04-16 13:45:27,756 : INFO : EPOCH 2 - PROGRESS: at 25.76% examples, 379778 words/s, in_qsize 5, out_qsize 0
# 2020-04-16 13:45:28,758 : INFO : EPOCH 2 - PROGRESS: at 44.79% examples, 381261 words/s, in_qsize 5, out_qsize 0
# 2020-04-16 13:45:29,765 : INFO : EPOCH 2 - PROGRESS: at 75.39% examples, 377878 words/s, in_qsize 5, out_qsize 0
# 2020-04-16 13:45:30,668 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-16 13:45:30,677 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-16 13:45:30,708 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-16 13:45:30,709 : INFO : EPOCH - 2 : training on 8591130 raw words (1503888 effective words) took 4.0s, 380446 effective words/s
# 2020-04-16 13:45:31,739 : INFO : EPOCH 3 - PROGRESS: at 26.83% examples, 397566 words/s, in_qsize 5, out_qsize 0
# 2020-04-16 13:45:32,743 : INFO : EPOCH 3 - PROGRESS: at 54.47% examples, 406694 words/s, in_qsize 5, out_qsize 0
# 2020-04-16 13:45:33,750 : INFO : EPOCH 3 - PROGRESS: at 79.33% examples, 408883 words/s, in_qsize 5, out_qsize 0
# 2020-04-16 13:45:34,444 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-16 13:45:34,446 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-16 13:45:34,460 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-16 13:45:34,462 : INFO : EPOCH - 3 : training on 8591130 raw words (1503201 effective words) took 3.7s, 401478 effective words/s
# 2020-04-16 13:45:35,470 : INFO : EPOCH 4 - PROGRESS: at 20.75% examples, 301272 words/s, in_qsize 4, out_qsize 1
# 2020-04-16 13:45:36,478 : INFO : EPOCH 4 - PROGRESS: at 34.21% examples, 280468 words/s, in_qsize 4, out_qsize 1
# 2020-04-16 13:45:37,483 : INFO : EPOCH 4 - PROGRESS: at 59.89% examples, 300816 words/s, in_qsize 5, out_qsize 0
# 2020-04-16 13:45:38,497 : INFO : EPOCH 4 - PROGRESS: at 79.98% examples, 308726 words/s, in_qsize 6, out_qsize 1
# 2020-04-16 13:45:39,038 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-16 13:45:39,041 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-16 13:45:39,060 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-16 13:45:39,061 : INFO : EPOCH - 4 : training on 8591130 raw words (1500961 effective words) took 4.6s, 326928 effective words/s
# 2020-04-16 13:45:40,067 : INFO : EPOCH 5 - PROGRESS: at 20.92% examples, 305329 words/s, in_qsize 6, out_qsize 1
# 2020-04-16 13:45:41,073 : INFO : EPOCH 5 - PROGRESS: at 48.97% examples, 393330 words/s, in_qsize 5, out_qsize 0
# 2020-04-16 13:45:42,098 : INFO : EPOCH 5 - PROGRESS: at 71.04% examples, 335310 words/s, in_qsize 5, out_qsize 2
# 2020-04-16 13:45:43,101 : INFO : EPOCH 5 - PROGRESS: at 82.53% examples, 318150 words/s, in_qsize 5, out_qsize 0
# 2020-04-16 13:45:43,714 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-16 13:45:43,715 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-16 13:45:43,732 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-16 13:45:43,733 : INFO : EPOCH - 5 : training on 8591130 raw words (1500702 effective words) took 4.7s, 321556 effective words/s
# 2020-04-16 13:45:43,734 : INFO : training on a 42955650 raw words (7510208 effective words) took 22.1s, 340487 effective words/s
# FastText(vocab=31, size=100, alpha=0.025)

# %% [markdown]
# Training hyperparameters
# ^^^^^^^^^^^^^^^^^^^^^^^^

# %% [markdown]
# Hyperparameters for training the model follow the same pattern as Word2Vec. FastText supports the following parameters from the original word2vec:
#
# - model: Training architecture. Allowed values: `cbow`, `skipgram` (Default `cbow`)
# - size: Size of embeddings to be learnt (Default 100)
# - alpha: Initial learning rate (Default 0.025)
# - window: Context window size (Default 5)
# - min_count: Ignore words with number of occurrences below this (Default 5)
# - loss: Training objective. Allowed values: `ns`, `hs`, `softmax` (Default `ns`)
# - sample: Threshold for downsampling higher-frequency words (Default 0.001)
# - negative: Number of negative words to sample, for `ns` (Default 5)
# - iter: Number of epochs (Default 5)
# - sorted_vocab: Sort vocab by descending frequency (Default 1)
# - threads: Number of threads to use (Default 12)
#
#
# In addition, FastText has three additional parameters:
#
# - min_n: min length of char ngrams (Default 3)
# - max_n: max length of char ngrams (Default 6)
# - bucket: number of buckets used for hashing ngrams (Default 2000000)
#
#
# Parameters ``min_n`` and ``max_n`` control the lengths of character ngrams that each word is broken down into while training and looking up embeddings. If ``max_n`` is set to 0, or to be lesser than ``min_n``\ , no character ngrams are used, and the model effectively reduces to Word2Vec.
#
#
#
# To bound the memory requirements of the model being trained, a hashing function is used that maps ngrams to integers in 1 to K. For hashing these character sequences, the `Fowler-Noll-Vo hashing function <http://www.isthe.com/chongo/tech/comp/fnv>`_ (FNV-1a variant) is employed.

# %% [markdown]
# **Note:** As in the case of Word2Vec, you can continue to train your model while using Gensim's native implementation of fastText.

# %% [markdown]
# ## Now we have a fastText model trained on Resumes
# <br>
# Now we need to take individual job postings to compare

# %%
# load jobs into df

local_jobs_cleaned_lemmatized_tokenized_path = '/Users/richardkuzma/coding/NLP_projects/job_recommender_project/data/cleaned_lemmatized_tokenized_jobs_dataset_madhab.csv'

jobs = pd.read_csv(local_jobs_cleaned_lemmatized_tokenized_path)

# %%
jobs.head()
# Out:
#                                                Title  \
# 0                            Chief Financial Officer
# 1                                Country Coordinator
# 2                                     BCC Specialist
# 3  Community Development, Capacity Building and C...
# 4                            Country Economist (NOB)
#
#                                              Company  \
# 0               AMERIA Investment Consulting Company
# 1          Caucasus Environmental NGO Network (CENN)
# 2                                       Manoff Group
# 3  Food Security Regional Cooperation and Stabili...
# 4      United Nations Development Programme, Armenia
#
#                                       JobDescription  \
# 0  AMERIA Investment Consulting Company is seekin...
# 1  Public outreach and strengthening of a growing...
# 2  The LEAD (Local Enhancement and Development fo...
# 3  Food Security Regional Cooperation and Stabili...
# 4  The United Nations Development Programme in Ar...
#
#                                         RequiredQual  \
# 0  To perform this job successfully, an\r\nindivi...
# 1  - Degree in environmentally related field, or ...
# 2  - Advanced degree in public health, social sci...
# 3  - Higher Education and/or professional experie...
# 4  - Minimum Masters Degree in Economics;\r\n- Mi...
#
#                                       JobRequirement  label  \
# 0  - Supervises financial management and administ...      1
# 1  - Working with the Country Director to provide...      2
# 2  - Identify gaps in knowledge and overseeing in...      3
# 3  - Assist the Tavush Marz communities and commu...      4
# 4  The incumbent under direct supervision of UNDP...      5
#
#                                             combined  \
# 0  chief financial officer ameria investment cons...
# 1  country coordinator public outreach strengthen...
# 2  bcc specialist lead local enhancement developm...
# 3  community development capacity building confli...
# 4  country economist nob united nations developme...
#
#                                       dirty_combined  \
# 0  Chief Financial Officer AMERIA Investment Cons...
# 1  Country Coordinator Public outreach and streng...
# 2  BCC Specialist The LEAD (Local Enhancement and...
# 3  Community Development, Capacity Building and C...
# 4  Country Economist (NOB) The United Nations Dev...
#
#                                   tokenized_combined  \
# 0  ['chief', 'financial', 'officer', 'ameria', 'i...
# 1  ['country', 'coordinator', 'public', 'outreach...
# 2  ['bcc', 'specialist', 'lead', 'local', 'enhanc...
# 3  ['community', 'development', 'capacity', 'buil...
# 4  ['country', 'economist', 'nob', 'united', 'nat...
#
#                                  lemmatized_combined
# 0  ['chief', 'financial', 'officer', 'ameria', 'i...
# 1  ['country', 'coordinator', 'public', 'outreach...
# 2  ['bcc', 'specialist', 'lead', 'local', 'enhanc...
# 3  ['community', 'development', 'capacity', 'buil...
# 4  ['country', 'economist', 'nob', 'united', 'nat...

# %%
jobs_list = jobs['lemmatized_combined'].tolist()

# %%
jobs.shape[0]
# Out:
# 13124

# %%
def pick_job():
    print("There are {} jobs".format(jobs.shape[0]))
    
    # Select a random int from 0 to length of rjob set
    rand_int = np.random.randint(1, jobs.shape[0]+1)
    
    
    
    # selection = 2
    selection = rand_int
    
    
    
    print ('\nselected job is ID #{}'.format(selection))
    
    # pick the job text and ID associated with the random int
    job_label = jobs.iloc[selection - 1, jobs.columns.get_loc('label')] #we could grab ID, but this works for non-indexed labels too
    job_title = jobs.iloc[selection - 1 ]['Title']
    job_company = jobs.iloc[selection - 1 ]['Company']
    job_description = jobs.iloc[selection - 1 ]['JobDescription']
    
    
    print('Job Posting ID is: {}'.format(job_label))
    print('Job Posting Title: {}'.format(job_title))
    print('Job Posting Company: {}'.format(job_company))
    print('Job Posting Description: {}'.format(job_description))
    
    #Convert the sample document into a list and use the infer_vector method to get a vector representation for it
    job_text_to_process = jobs['lemmatized_combined'][selection - 1]
    
    return job_text_to_process

# %%
def given_job_find_similar_resumes(job_you_pick):
  
    #find all distances between chosen job and each resume
    temp_distance = []
    min_dist = float("inf")
    min_index = float("inf")


    # for i in range len(resume_sentences): 
    for i in range (0, len(resumes_sentences)):
        dist = model.wmdistance(job_you_pick, resumes_sentences[i])
        if dist < min_dist:
            min_dist = dist
            min_index = i
        temp_distance.append((dist, i))

    #sort list of tuples
    temp_distance.sort(key = operator.itemgetter(0))
    temp_distance

    num_similar = 10 #or 10, 20, 25
    print('\nPrinting {} most similar candidates...\n'.format(num_similar))
    for i in range(0,num_similar):
        print('\n#{} most similar job'.format(i+1))
        print('Resume ID from list: {}'.format(temp_distance[i][1]))
        print('WM Distance: {}'.format(temp_distance[i][0]))
        print('Resume ID from df: {}'.format(resumes.iloc[temp_distance[i][1]]['ID']))
        print('Resume text (500 chars): {}'.format(resumes.iloc[temp_distance[i][1]]['resume'][0:500]))

# %%
chosen_job = pick_job()
# Out:
# There are 13124 jobs
#
# selected job is ID #3187
# Job Posting ID is: 3187
# Job Posting Title: PR Manager
# Job Posting Company: Megafood LLC
# Job Posting Description: Megafood LLC is seeking a candidate for the position
# of PR Manager who will coordinate the company's market research,
# marketing stratagy, product development and public relations activities.
# The PR Manager will initiate, develop and manage PR programs to support
# and enhance the overall marketing, sales and business goals of the
# company.

# %%
given_job_find_similar_resumes(chosen_job)
# Out:
# /Users/richardkuzma/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `wmdistance` (Method will be removed in 4.0.0, use self.wv.wmdistance() instead).
#   # This is added back by InteractiveShellApp.init_path()
# 2020-04-16 14:39:59,608 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:39:59,614 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 7820 corpus positions)
# 2020-04-16 14:39:59,634 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:39:59,637 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 2855 corpus positions)
# 2020-04-16 14:39:59,659 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:39:59,663 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 8309 corpus positions)
# 2020-04-16 14:39:59,694 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:39:59,705 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 11208 corpus positions)
# 2020-04-16 14:39:59,735 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:39:59,740 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 7850 corpus positions)
# 2020-04-16 14:39:59,765 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:39:59,769 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 7820 corpus positions)
# 2020-04-16 14:39:59,797 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:39:59,804 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 9127 corpus positions)
# 2020-04-16 14:39:59,850 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:39:59,854 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 11369 corpus positions)
# 2020-04-16 14:39:59,891 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:39:59,897 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 11989 corpus positions)
# 2020-04-16 14:39:59,924 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:39:59,927 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 3736 corpus positions)
# 2020-04-16 14:39:59,974 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:39:59,980 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 9326 corpus positions)
# 2020-04-16 14:40:00,011 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:00,017 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 6306 corpus positions)
# 2020-04-16 14:40:00,045 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:00,053 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 7538 corpus positions)
# 2020-04-16 14:40:00,092 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:00,107 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 6551 corpus positions)
# 2020-04-16 14:40:00,140 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:00,146 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 8953 corpus positions)
# 2020-04-16 14:40:00,177 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:00,196 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 8309 corpus positions)
# 2020-04-16 14:40:00,238 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:00,241 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 5428 corpus positions)
# 2020-04-16 14:40:00,274 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:00
: INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:58,911 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 5375 corpus positions)
# 2020-04-16 14:40:58,951 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:58,953 : INFO : built Dictionary(30 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 2973 corpus positions)
# 2020-04-16 14:40:58,973 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:58,975 : INFO : built Dictionary(29 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 1357 corpus positions)
# 2020-04-16 14:40:59,000 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,048 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 57482 corpus positions)
# 2020-04-16 14:40:59,095 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,097 : INFO : built Dictionary(30 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 2068 corpus positions)
# 2020-04-16 14:40:59,123 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,126 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 2564 corpus positions)
# 2020-04-16 14:40:59,150 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,152 : INFO : built Dictionary(30 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 3197 corpus positions)
# 2020-04-16 14:40:59,184 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,189 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 5856 corpus positions)
# 2020-04-16 14:40:59,215 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,218 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 4561 corpus positions)
# 2020-04-16 14:40:59,252 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,267 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 9772 corpus positions)
# 2020-04-16 14:40:59,295 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,299 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 4659 corpus positions)
# 2020-04-16 14:40:59,327 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,330 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 3004 corpus positions)
# 2020-04-16 14:40:59,369 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,376 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 8952 corpus positions)
# 2020-04-16 14:40:59,420 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,428 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 3641 corpus positions)
# 2020-04-16 14:40:59,473 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,475 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 2465 corpus positions)
# 2020-04-16 14:40:59,508 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,511 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 7133 corpus positions)
# 2020-04-16 14:40:59,543 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,549 : INFO : built Dictionary(30 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 4355 corpus positions)
# 2020-04-16 14:40:59,607 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,613 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 12840 corpus positions)
# 2020-04-16 14:40:59,644 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,646 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 4352 corpus positions)
# 2020-04-16 14:40:59,682 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,689 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 11759 corpus positions)
# 2020-04-16 14:40:59,747 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,749 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 2389 corpus positions)
# 2020-04-16 14:40:59,770 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,772 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 4181 corpus positions)
# 2020-04-16 14:40:59,802 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,804 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 3147 corpus positions)
# 2020-04-16 14:40:59,844 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,857 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 36454 corpus positions)
# 2020-04-16 14:40:59,890 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,894 : INFO : built Dictionary(30 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 4199 corpus positions)
# 2020-04-16 14:40:59,932 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,934 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 3315 corpus positions)
# 2020-04-16 14:40:59,959 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:40:59,969 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 20102 corpus positions)
# 2020-04-16 14:41:00,018 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:41:00,021 : INFO : built Dictionary(30 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 3449 corpus positions)
# 2020-04-16 14:41:00,047 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:41:00,056 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 3529 corpus positions)
# 2020-04-16 14:41:00,114 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:41:00,118 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 2523 corpus positions)
# 2020-04-16 14:41:00,142 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:41:00,151 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 3008 corpus positions)
# 2020-04-16 14:41:00,182 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:41:00,185 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 6517 corpus positions)
# 2020-04-16 14:41:00,231 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:41:00,232 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 3896 corpus positions)
# 2020-04-16 14:41:00,278 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-04-16 14:41:00,290 : INFO : built Dictionary(31 unique tokens: [' ', "'", ',', '[', ']']...) from 2 documents (total 36091 corpus positions)
# Printing 10 most similar candidates...
#
#
# #1 most similar job
# Resume ID from list: 692
# WM Distance: 0.16037376807236195
# Resume ID from df: 693
# Resume text (500 chars): matt arnzen mattmattarnzencom    portland professional summary marketing professional fifteen years progressive experience digital marketing product management user experience design accomplished creative development website operations digital platform management collaborating effectively stakeholders vendors clients digital marketing product management content management marketing automation website design development search engine optimization web analytics reporting customer relationship mana
#
# #2 most similar job
# Resume ID from list: 437
# WM Distance: 0.16067475820688432
# Resume ID from df: 438
# Resume text (500 chars): steve jones business operations manager dayjob ltd big peg birmingham b nf    e infodayjobcom personal statment e infodayjobcom progressive business operations manager particular strength driving performance reducing inefficiencies cutting costs steve self motivated focused candidate four years experience working senior managerial roles self sufficient resourceful responsive cooperative knowledgeable approach work well professional attitude dealing operational issues may arise even though leads
#
# #3 most similar job
# Resume ID from list: 598
# WM Distance: 0.16313769448470214
# Resume ID from df: 599
# Resume text (500 chars): customer service rep resume template mary rodrigues  williams street nottingham telno   emailmrymailcom career objective excel providing customer service long term career plan build sustaining career organization summary qualifications excellent interpersonal communication skills knack handling even toughest customers ready solutions calm feel satisfied good personality amiable manners get people levels career experiencejob history  till date contemporary automobiles pvt ltd customer service rep
#
# #4 most similar job
# Resume ID from list: 136
# WM Distance: 0.16437028506549461
# Resume ID from df: 137
# Resume text (500 chars): application development manager resume dan charlie  woodrow lane atlanta ga  cell    e mail charlieyahoocom career objective looking position application development manager utilize progressive ten years experience application development management renowned organization core competencies extensive knowledge applications technological solutions especially complex business applications strong organizational problem solving skills excellent communication presentation skills good knowledge multi pr
#
# #5 most similar job
# Resume ID from list: 664
# WM Distance: 0.1682326241102516
# Resume ID from df: 665
# Resume text (500 chars): client name    customer lane city name  nameanywherecom career objective driven results oriented sales marketing executive expertise dealer consumer sales eager contribute optimizing revenue profit performance progressive organization skills include dynamic communication business development strategic planning fiscal administration national account management consulting e commerce advertising high technology talents professional profile nearly three decades successful domestic international sale
#
# #6 most similar job
# Resume ID from list: 645
# WM Distance: 0.1795065317780564
# Resume ID from df: 646
# Resume text (500 chars): before  street xefxxb hackensack nj     mobile sherlockoptonlinenet john sherlock summary self starting goal oriented sales professional whose extensive experience promoted success high quality company ranked number one sales volume nationally knowledgeable phases client service track record outstanding customer satisfaction proven success establishing maintaining loyal customer base consistently honored exceeding sales service expectations accomplishments nissan sales guild recipient   general
#
# #7 most similar job
# Resume ID from list: 1147
# WM Distance: 0.18301571016465967
# Resume ID from df: 1148
# Resume text (500 chars): debt management directors resume template alex wayne  worchester shire rd norwood ohio  phone   alexgoodgmailcom objective looking challenging position debt management director reputable organization view use wide experience benefit organization summary qualifications self motivated hardworking person diplomatic strong customer service skills excellent communications interpersonal skills good team player negotiation presentation skills strong organizational analytical problem solving skills mult
#
# #8 most similar job
# Resume ID from list: 0
# WM Distance: 0.18344135833939493
# Resume ID from df: 1
# Resume text (500 chars): john h smith phr    po box  callahan fl  infogreatresumesfastcom approachable innovator passion human resources senior human resources professional personable analytical flexible senior hr professional multifaceted expertise seasoned benefits administrator extensive experience working highly paid professionals client relationship based settings dynamic team leader capable analyzing alternatives identifying tough choices communicating total value benefit compensation packages senior level executi
#
# #9 most similar job
# Resume ID from list: 5
# WM Distance: 0.18344135833939493
# Resume ID from df: 6
# Resume text (500 chars): john h smith phr    po box  callahan fl  infogreatresumesfastcom approachable innovator passion human resources senior human resources professional personable analytical flexible senior hr professional multifaceted expertise seasoned benefits administrator extensive experience working highly paid professionals client relationship based settings dynamic team leader capable analyzing alternatives identifying tough choices communicating total value benefit compensation packages senior level executi
#
# #10 most similar job
# Resume ID from list: 632
# WM Distance: 0.18587641140774888
# Resume ID from df: 633
# Resume text (500 chars): john doe city xexxa    xexxa emailaddresscom wine spirits sales professional sales professional five years successful sales competitive southern california market established relationships many customers industry leaders within local wine spirits industry proven ability increase product visibility variety sales initiatives excellent closer demonstrated fifteen years sales experience exceptional influencer able identify motivates individuals persuade highly capable analyzing identifying forecasti
